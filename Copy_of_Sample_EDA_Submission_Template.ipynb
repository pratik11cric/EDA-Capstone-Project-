# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik11cric/EDA-Capstone-Project-/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Automobile Industry Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Pratik**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# The automobile industry is a complex and competitive market, with numerous manufactures and models available to consumers . To better understand this market and identify trends, patterns and insights , we conducted an analysis of an automobile dataset .
# This project this project summary provides an overview of the objectives , and the conclusions drawn from the analysis . The primary objective of the project is to explore and analyze the dataset using Python Libraries such as Pandas,NumPy,Matplotlib, and Seaborn . Cleaned and preprocessed the dataset to handle missing values and inconsistent data formats . Applied univariate and multivarite analysis techniques to understand the distribution of vehicle attributes and their relationships . utilized various visualization tools tolls including pairplot,barplpot,pieplot, etc to illustrate findings .
# Length ,width , bore,  stroke and height followed a normal distribution while engine related attributes were skewed .
# This project focuses on the analysis of an automobile dataset to understand various features of vehicles, including attributes like price, horsepower, engine size, and more.                                                                                                                               The goal is to use Python and its data analysis libraries to clean, preprocess, and analyze the data, extracting insights and trends that could be valuable for automotive companies, potential buyers, or analysts in the automotive industry.                                                                                                                         The automobile dataset typically contains several columns such as car make, model, year, price, horsepower, engine type, number of doors, weight, and fuel efficiency. These attributes can vary across different vehicles and manufacturers. The dataset may also include missing values, outliers, and categorical variables that need to be cleaned and preprocessed for effective analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# An automobile dataset has conducted market resesrach for its new model and wants to identify thw key factors that are most important to customer when they will purchase car.
#
# The dataset contains 205 rows and 26 columns .
#
# Identify the key factors that are most important to customer when purchasing car.
# Predict key factors. Provide recommendation to the automobile company for it's new model.
#
# What kind of factorsare most important to the customers. How do price and mileage affect car sales. Which car models are most popular among customers.
#
# Evaluate model performance based on (MAE) Mean Absolute Error.
# Evaluate model performance based on R-squared.
#
# This problem statement defines the goals and questions to be addressed using the automobile dataset.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# **The analysis of an automobile dataset offers a multitude of opportunities for businesses in the automotive industry. The data collected from different vehicle features can help automotive companies, car dealerships, and other stakeholders gain valuable insights for decision-making, improving product offerings, and enhancing customer satisfaction. Below are several key business objectives that can be addressed through the analysis of an automobile dataset.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Copy of automobile_data.csv"

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (205, 26)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

# %%
print(df.isnull().sum())
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# The dataset given is a dataset from automobile industry , and we have to analyse the insights behind it.
#
# The above dataset has 205 rows and 26 columns.There are no missing values and no duplicate values.
#
# By analyzing an automobile dataset,we can gain a deeper understanding of automotive industry , customer prefrences , and market trends , which can inform business decisions and drive growth.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# 1. **Symboling**: A numerical value that represents the insurance risk rating of the vehicle, with higher values indicating higher risk.
# 2. **Normalized-losses**: A numerical value representing the average loss payment per insured vehicle year, normalized for all vehicles.
# 3. **Make**: The manufacturer of the vehicle (e.g., Toyota, Honda, Ford).
# 4. **Fuel-type**: The type of fuel used by the vehicle (e.g., gasoline, diesel).
# 5. **Aspiration**: The type of aspiration used by the vehicle's engine (e.g., naturally aspirated, turbocharged).
# 6. **Num-of-doors**: The number of doors on the vehicle.
# 7. **Body-style**: The style of the vehicle's body (e.g., sedan, SUV, wagon).
# 8. **Drive-wheels**: The type of drive wheels used by the vehicle (e.g., front-wheel drive, rear-wheel drive, all-wheel drive).
# 9. **Engine-location**: The location of the vehicle's engine (e.g., front, rear).
# 10. **Wheel-base**: The distance between the front and rear wheels of the vehicle.
# 11. **Length**: The overall length of the vehicle.
# 12. **Width**: The overall width of the vehicle.
# 13. **Height**: The overall height of the vehicle.
# 14. **Curb-weight**: The weight of the vehicle without passengers or cargo.
# 15. **Engine-type**: The type of engine used by the vehicle (e.g., V6, inline-4).
# 16. **Num-of-cylinders**: The number of cylinders in the vehicle's engine.
# 17. **Engine-size**: The size of the vehicle's engine in liters.
# 18. **Fuel-system**: The type of fuel system used by the vehicle (e.g., fuel injection, carburetor).
# 19. **Bore**: The diameter of the engine's cylinders.
# 20. **Stroke**: The distance the piston travels in the engine's cylinders.
# 21. **Compression-ratio**: The ratio of the engine's compression.
# 22. **Horsepower**: The power output of the vehicle's engine.
# 23. **Peak-rpm**: The engine speed at which the vehicle produces its maximum horsepower.
# 24. **City-mpg**: The vehicle's fuel efficiency in city driving conditions.
# 25. **Highway-mpg**: The vehicle's fuel efficiency in highway driving conditions.
# 26. **Price**: The price of the vehicle.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %%
print(df.nunique)
# Out:
# <bound method DataFrame.nunique of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
symboling_map = {-2:'very low',-1:'low',0:'average',1:'above average',2:'high',3:'very high'}
df["symboling"] = df["symboling"].map(symboling_map)

# %%
df["symboling"].value_counts()
# Out:
# symboling
# average          67
# above average    54
# high             32
# very high        27
# low              22
# very low          3
# Name: count, dtype: int64

# %%
df["normalized-losses"] = df["normalized-losses"].str.replace("?","0")
df["normalized-losses"] = df["normalized-losses"].astype(int)

# %%
df["bore"] = df["bore"].str.replace("?","0")
df["bore"] = df["bore"].astype(float)

# %%
df["stroke"] = df["stroke"].str.replace("?","0")
df["stroke"] = df["stroke"].astype(float)

# %%
df["horsepower"] = df["horsepower"].str.replace("?","0")
df["horsepower"] = df["horsepower"].astype(int)

# %%
df["peak-rpm"] = df["peak-rpm"].str.replace("?","0")
df["peak-rpm"] = df["peak-rpm"].astype(int)

# %%
df["price"] = df["price"].str.replace("?","0")
df["price"] = df["price"].astype(int)

# %%
min_value = df["price"].min()
max_value = df["price"].max()
print(min_value)
print(max_value)
# Out:
# 0
# 45400

# %%
df["num-of-doors"] = df["num-of-doors"].str.replace("?","0")

# %%
print(df["num-of-doors"].unique())
df["num-of-doors"].value_counts()
# Out:
# ['two' 'four' '0']
# num-of-doors
# four    114
# two      89
# 0         2
# Name: count, dtype: int64

# %%
print(df["make"].unique())
df["make"].value_counts()
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
print(df["fuel-type"].unique())
df["fuel-type"].value_counts()
# Out:
# ['gas' 'diesel']
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
print(df["aspiration"].unique())
df["aspiration"].value_counts()
# Out:
# ['std' 'turbo']
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
print(df["body-style"].unique())
df["body-style"].value_counts()
# Out:
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
print(df["drive-wheels"].unique())
df["drive-wheels"].value_counts()
# Out:
# ['rwd' 'fwd' '4wd']
# drive-wheels
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
print(df["engine-location"].unique())
df["engine-location"].value_counts()
# Out:
# ['front' 'rear']
# engine-location
# front    202
# rear       3
# Name: count, dtype: int64

# %%
print(df["engine-type"].unique())
df["engine-type"].value_counts()
# Out:
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# engine-type
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64

# %%
print(df["num-of-cylinders"].unique())
df["num-of-cylinders"].value_counts()
# Out:
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# num-of-cylinders
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: count, dtype: int64

# %%
print(df["fuel-system"].unique())
df["fuel-system"].value_counts()
# Out:
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# fuel-system
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
df["normalized-losses"].value_counts()
# Out:
# normalized-losses
# 0      41
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 74      5
# 103     5
# 168     5
# 95      5
# 102     5
# 94      5
# 65      5
# 85      5
# 93      4
# 106     4
# 118     4
# 122     4
# 148     4
# 154     3
# 83      3
# 125     3
# 115     3
# 137     3
# 101     3
# 194     2
# 197     2
# 188     2
# 164     2
# 158     2
# 192     2
# 110     2
# 145     2
# 113     2
# 81      2
# 89      2
# 87      2
# 108     2
# 119     2
# 153     2
# 129     2
# 98      1
# 121     1
# 107     1
# 78      1
# 231     1
# 142     1
# 77      1
# 186     1
# 90      1
# 256     1
# Name: count, dtype: int64

# %%
df["bore"].value_counts()
# Out:
# bore
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.31     8
# 3.43     8
# 3.78     8
# 3.27     7
# 2.91     7
# 3.58     6
# 3.05     6
# 3.54     6
# 3.39     6
# 3.70     5
# 3.01     5
# 3.35     4
# 0.00     4
# 3.74     3
# 3.17     3
# 3.59     3
# 3.50     2
# 3.24     2
# 3.13     2
# 3.47     2
# 3.94     2
# 3.80     2
# 3.63     2
# 3.33     2
# 2.68     1
# 3.76     1
# 3.08     1
# 2.92     1
# 3.60     1
# 3.34     1
# 2.99     1
# 2.54     1
# 3.61     1
# Name: count, dtype: int64

# %%
df["stroke"].value_counts()
# Out:
# stroke
# 3.40    20
# 3.23    14
# 3.15    14
# 3.03    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.58     6
# 3.11     6
# 3.07     6
# 3.19     6
# 3.27     6
# 3.41     6
# 3.50     6
# 3.52     5
# 3.64     5
# 3.86     4
# 3.47     4
# 0.00     4
# 3.54     4
# 2.90     3
# 3.90     3
# 2.68     2
# 2.80     2
# 3.08     2
# 4.17     2
# 3.10     2
# 2.19     2
# 2.76     1
# 3.16     1
# 3.12     1
# 3.21     1
# 2.07     1
# 2.36     1
# 2.87     1
# Name: count, dtype: int64

# %%
df["horsepower"].value_counts()
# Out:
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 114     6
# 62      6
# 101     6
# 160     6
# 102     5
# 76      5
# 97      5
# 82      5
# 145     5
# 84      5
# 123     4
# 86      4
# 92      4
# 111     4
# 121     3
# 90      3
# 182     3
# 85      3
# 73      3
# 152     3
# 207     3
# 112     2
# 56      2
# 156     2
# 161     2
# 52      2
# 162     2
# 0       2
# 155     2
# 100     2
# 94      2
# 184     2
# 176     2
# 115     1
# 154     1
# 140     1
# 48      1
# 120     1
# 64      1
# 135     1
# 262     1
# 78      1
# 60      1
# 58      1
# 55      1
# 288     1
# 143     1
# 142     1
# 200     1
# 175     1
# 72      1
# 134     1
# 106     1
# Name: count, dtype: int64

# %%
df["price"].value_counts()
# Out:
# price
# 0        4
# 16500    2
# 6229     2
# 7609     2
# 7957     2
#         ..
# 16845    1
# 19045    1
# 21485    1
# 22470    1
# 22625    1
# Name: count, Length: 187, dtype: int64

# %%
df["peak-rpm"].value_counts()
# Out:
# peak-rpm
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 4500     7
# 5800     7
# 5250     7
# 4200     5
# 4150     5
# 4750     4
# 4350     4
# 4250     3
# 5100     3
# 5900     3
# 4400     3
# 0        2
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: count, dtype: int64

# %%
df["wheel-base"].value_counts()
# Out:
# wheel-base
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 98.4      7
# 97.3      7
# 96.3      6
# 107.9     6
# 99.1      6
# 98.8      6
# 100.4     6
# 104.3     6
# 97.2      5
# 109.1     5
# 102.4     5
# 95.9      5
# 93.1      5
# 101.2     4
# 95.3      4
# 114.2     4
# 97.0      4
# 105.8     3
# 110.0     3
# 89.5      3
# 103.5     3
# 91.3      2
# 115.6     2
# 96.1      2
# 103.3     2
# 99.8      2
# 88.6      2
# 113.0     2
# 96.9      2
# 102.9     2
# 104.5     2
# 86.6      2
# 104.9     2
# 102.0     1
# 96.0      1
# 94.3      1
# 88.4      1
# 99.5      1
# 99.4      1
# 112.0     1
# 102.7     1
# 99.2      1
# 95.1      1
# 93.0      1
# 106.7     1
# 96.6      1
# 120.9     1
# 93.3      1
# 108.0     1
# Name: count, dtype: int64

# %%
df["height"].value_counts()
# Out:
# height
# 50.8    14
# 52.0    12
# 55.7    12
# 54.5    10
# 54.1    10
# 55.5     9
# 56.7     8
# 54.3     8
# 52.6     7
# 51.6     7
# 56.1     7
# 53.0     6
# 54.9     6
# 52.8     6
# 50.2     6
# 50.6     5
# 53.7     5
# 55.1     5
# 58.7     4
# 49.6     4
# 53.3     4
# 53.5     3
# 52.5     3
# 59.1     3
# 57.5     3
# 56.2     3
# 49.7     3
# 49.4     2
# 50.5     2
# 54.4     2
# 56.3     2
# 59.8     2
# 48.8     2
# 53.9     2
# 51.4     2
# 56.5     2
# 54.7     2
# 52.4     1
# 53.2     1
# 53.1     1
# 55.9     1
# 58.3     1
# 55.4     1
# 51.0     1
# 47.8     1
# 54.8     1
# 56.0     1
# 55.2     1
# 55.6     1
# Name: count, dtype: int64

# %%
df["length"].value_counts()
# Out:
# length
# 157.3    15
# 188.8    11
# 186.7     7
# 166.3     7
# 171.7     7
#          ..
# 181.5     1
# 181.7     1
# 159.3     1
# 165.7     1
# 183.1     1
# Name: count, Length: 75, dtype: int64

# %%
df["width"].value_counts()
# Out:
# width
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 64.2     6
# 66.3     6
# 65.6     6
# 67.2     6
# 66.9     5
# 67.9     5
# 68.9     4
# 64.8     4
# 65.7     4
# 71.7     3
# 71.4     3
# 70.3     3
# 65.0     3
# 63.9     3
# 67.7     2
# 64.1     2
# 66.1     2
# 69.6     2
# 68.3     2
# 64.6     2
# 70.9     1
# 66.2     1
# 66.4     1
# 60.3     1
# 62.5     1
# 66.0     1
# 61.8     1
# 70.6     1
# 72.0     1
# 68.0     1
# 70.5     1
# 63.4     1
# 66.6     1
# 72.3     1
# 68.8     1
# Name: count, dtype: int64

# %%
df["engine-size"].value_counts()
# Out:
# engine-size
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 110    12
# 90     12
# 109     8
# 120     7
# 141     7
# 181     6
# 152     6
# 146     6
# 121     6
# 156     5
# 91      5
# 136     5
# 130     4
# 183     4
# 164     3
# 194     3
# 70      3
# 209     3
# 171     3
# 132     2
# 131     2
# 140     2
# 258     2
# 134     2
# 234     2
# 61      1
# 80      1
# 79      1
# 111     1
# 119     1
# 326     1
# 308     1
# 151     1
# 304     1
# 103     1
# 203     1
# 161     1
# 173     1
# 145     1
# Name: count, dtype: int64

# %%
df["curb-weight"].value_counts()
# Out:
# curb-weight
# 2385    4
# 1918    3
# 1989    3
# 2275    3
# 2191    2
#        ..
# 2952    1
# 3049    1
# 3012    1
# 3217    1
# 3062    1
# Name: count, Length: 171, dtype: int64

# %%
df["width"].value_counts()
# Out:
# width
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 64.2     6
# 66.3     6
# 65.6     6
# 67.2     6
# 66.9     5
# 67.9     5
# 68.9     4
# 64.8     4
# 65.7     4
# 71.7     3
# 71.4     3
# 70.3     3
# 65.0     3
# 63.9     3
# 67.7     2
# 64.1     2
# 66.1     2
# 69.6     2
# 68.3     2
# 64.6     2
# 70.9     1
# 66.2     1
# 66.4     1
# 60.3     1
# 62.5     1
# 66.0     1
# 61.8     1
# 70.6     1
# 72.0     1
# 68.0     1
# 70.5     1
# 63.4     1
# 66.6     1
# 72.3     1
# 68.8     1
# Name: count, dtype: int64

# %%
df["length"].value_counts()
# Out:
# length
# 157.3    15
# 188.8    11
# 186.7     7
# 166.3     7
# 171.7     7
#          ..
# 181.5     1
# 181.7     1
# 159.3     1
# 165.7     1
# 183.1     1
# Name: count, Length: 75, dtype: int64

# %%
min_value = df["height"].min()
max_value = df["height"].max()
print(min_value)
print(max_value)
# Out:
# 47.8
# 59.8

# %%
min_value = df["width"].min()
max_value = df["width"].max()
print(min_value)
print(max_value)
# Out:
# 60.3
# 72.3

# %%
min_value = df["length"].min()
max_value = df["length"].max()
print(min_value)
print(max_value)
# Out:
# 141.1
# 208.1

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# We did lot of manipulation in this automobile dataset. We replaced
# "?" as "0".
#
# I changed normalized losses from obj. to int64.
#
# I changed bore from obj. to float64.
#
# I changed stroke from obj. to float64.
#
# I changed horsepower from obj. to int64.
#
# I changed peak rpm from obj. to int64.
#
# I changed price from obj. to int64.
#
#
#
# We may need to handle missing values in the dataset by imputing them with mean, median, or mode values.
# We may need to normalize the data to ensure that all variables are on the same scale.
# We may need to transform the data to ensure that it meets the assumptions of the analysis.
#
# We may need to scale the features to ensure that all variables are on the same scale.
# We may need to create new features from existing ones to improve the analysis.
# We may need to encode categorical variables into numerical variables.
#
# Data Reduction
# We may need to reduce the number of variables in the dataset to improve the analysis.
# We may need to select the most relevant features for the analysis.
#
# We may need to plot histograms to understand the distribution of the data.
# We may need to plot scatter plots to understand the relationships between variables.
# We may need to plot bar charts to understand the distribution of categorical variables.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %%
df["make"].value_counts().plot(kind = "bar",color=sns.color_palette("magma"),edgecolor="m")
plt.xlabel("CAR COMPANY",fontsize=15)
plt.ylabel("COUNT",fontsize=15)
plt.title("CAR COMPANY VS COUNT",fontsize=15)
# Out:
# Text(0.5, 1.0, 'CAR COMPANY VS COUNT')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By choosing barplot , we can effectively visualize and compare the counts of different car companies , making it easier to understand the data and idetify patterns .
#
# Barplots are easy to read to understand , with each bar represnting a category and the height of the bar representing the count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot , we can gain insights into the popularity of different car companies , market trends and competitor analysis , which can inform business decision.
#
# The car with the highest count has the highest sales. The car company with the lowest count has the lowest sales .
#
# Tcar company with thw highest count is the most popular among customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot , of car company vs counts a company can gain valuable insights that can inform business decisions , drive growth , and improve customer satisfaction .
#
# Focusing too much on the most popular car companies or models can lead to neglect of other models or segments , potentially missing out on opportunities .

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %%
df["fuel-type"].value_counts().plot(kind = "pie",autopct="%1.1f%%",shadow=True,explode=[0.1,0.1],colors=sns.color_palette("rainbow"))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By choosing a pie plot, we can effectively visualize and compare the proportions of different fuel types, making it easier to understand the data and identify trends.
#
# Fuel type is a categorical variable, making a pie plot a suitable choice for displaying the distribution of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of fuel type, we can gain insights into the distribution of different fuel types, market demand, and competitor activity, which can inform business decisions.
#
#
# The fuel type with the largest proportion is the most common.The fuel type with the smallest proportion is the least common.
#
# The pie plot can be used to understand market demand for different fuel types.
#
# The insights from the pie plot can be used to inform product development, such as developing more products that use the most common fuel type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the pie plot of fuel type, a company can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the pie plot can inform business decisions, such as which fuel types to prioritize or which products to develop.
# The analysis can provide a better understanding of the market, including the distribution of different fuel types and market demand.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %%
plt.figure(figsize=(25,6))
x = df["make"]
y = df["price"]
plt.bar(x,y,color=sns.color_palette("magma"),width=0.4,edgecolor="black")
plt.xlabel("CAR COMPANY",fontsize=25)
plt.ylabel("PRICE",fontsize=25)
plt.title("CAR COMPANY VS PRICE",fontsize=25)
# Out:
# Text(0.5, 1.0, 'CAR COMPANY VS PRICE')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By choosing a bar plot, we can effectively visualize and compare the prices of different makes, making it easier to understand the data and identify trends.
#
# Make is a categorical variable, making a bar plot a suitable choice for displaying the distribution of different categories.
#
#  A bar plot makes it easy to compare the prices of different makes, allowing us to identify which ones are most expensive or least expensive.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of make vs price, we can gain insights into the distribution of prices across different makes, market demand, and competitor activity, which can inform business decisions.
#
# The make with the highest price is the most expensive. The make with the lowest price is the least expensive.
#
# The bar plot makes it easy to compare the prices of different makes, allowing us to identify which ones are most expensive or least expensive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of make vs price, a company can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
#  The insights gained from the bar plot can inform business decisions, such as which makes to prioritize or which products to develop.
#
#  The analysis can provide a better understanding of the market, including the distribution of prices across different makes and market demand.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import plotly.graph_objs as go

# %%
fig = go.Figure(data=[go.Pie(labels=df["symboling"], values=df["price"])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a pie plot for symboling, we can effectively visualize and compare the proportions of different symbols, making it easier to understand the data and identify trends.
#
# Symbology is a categorical variable, making a pie plot a suitable choice for displaying the distribution of different categories.
# A pie plot is effective for visualizing the proportion of each category, allowing us to see the relative size of each symbol.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of symboling, we can gain insights into the distribution of symbols, market demand, and competitor activity, which can inform business decisions.
#
# The symbol with the largest proportion is the most common.The symbol with the smallest proportion is the least common.
# Proportion of each symbol: The pie plot shows the proportion of each symbol, allowing us to understand the relative size of each category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of symboling, a company can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the pie plot can inform business decisions, such as which symbols to prioritize or which products to develop.
# Market understanding: The analysis can provide a better understanding of the market, including the distribution of symbols and market demand.
#
# Overemphasizing popular symbols can lead to poor resource allocation, with too many resources focused on a single area.
#
# Missed opportunities: Focusing too much on popular symbols can lead to missed opportunities in other areas

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %%
df["body-style"].value_counts()
# Out:
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,10))
body_style = ['sedan','hatchback','wagon','hardtop','convertible',]
quantity = [96,70,25,8,6]

pie1 = plt.pie(quantity,labels=body_style,autopct='%1.1f%%',radius=2)
pie2 = plt.pie([5],radius=1,colors='w')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a pie plot for body style in an automobile dataset, we can effectively visualize and compare the proportions of different body styles, making it easier to understand the data and identify trends.
#
# Body style is a categorical variable, making a pie plot a suitable choice for displaying the distribution of different categories.
#
# A pie plot is effective for visualizing the proportion of each category, allowing us to see the relative size of each body style.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of body style, we can gain insights into the distribution of body styles, market demand, and competitor activity, which can inform business decisions.
#
# The body style with the largest proportion is the most common.
# The body style with the smallest proportion is the least common.
# The pie plot shows the proportion of each body style, allowing us to understand the relative size of each category.
#
# The body style with the largest proportion is the most popular. The body style with the smallest proportion is the least popular.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of body style, a company can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction
#
# The insights gained from the pie plot can inform business decisions, such as which body styles to prioritize or which products to develop.
#
# The analysis can provide a better understanding of the market, including the distribution of body styles and market demand.
# The pie plot can be used to analyze the competition, identifying which body styles are most commonly used by competitors.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %%
plt.figure(figsize=(25,6))
x = df["make"]
y = df["symboling"]
plt.bar(x,y,color=sns.color_palette("rainbow"),width=0.4,edgecolor="black")
plt.xlabel("CAR COMPANY",fontsize=25)
plt.ylabel("RISK",fontsize=25)
plt.title("CAR COMPANY VS RISK",fontsize=25)
# Out:
# Text(0.5, 1.0, 'CAR COMPANY VS RISK')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a bar plot for car company vs risk, we can effectively visualize and compare the risk levels of different car companies, making it easier to understand the data and identify trends.
#
# Car company is a categorical variable, and risk is a numerical variable, making a bar plot a suitable choice for displaying the relationship between the two.
#
# A bar plot makes it easy to compare the risk levels of different car companies, allowing us to identify which companies have higher or lower risk levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of car company vs risk, we can gain insights into the risk levels of different car companies, informing business decisions and driving growth.
#
# The bar plot shows the risk levels of different car companies, allowing us to compare and identify which companies have higher or lower risk levels.
#
# The bar plot makes it easy to identify the car companies with the highest and lowest risk levels. The bar plot allows us to compare the risk levels of different car companies, identifying which companies have similar or different risk levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of car company vs risk, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the bar plot can inform business decisions, such as which car companies to invest in or partner with.
# Risk assessment: The bar plot can be used to assess the risk levels of different car companies, allowing businesses to make informed decisions.
# Market understanding: The analysis can provide a better understanding of the market, including the risk levels of different car companies.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %%
plt.figure(figsize=(10,4))
x = df["engine-type"]
y = df["horsepower"]
plt.bar(x,y,color=sns.color_palette("Set1"),width=0.2,edgecolor="black")
plt.xlabel("ENGINE TYPE",fontsize=15)
plt.ylabel("AVERAGE HORSEPOWER",fontsize=15)
# Out:
# Text(0, 0.5, 'AVERAGE HORSEPOWER')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a bar plot for average horsepower vs engine type, we can effectively visualize and compare the average horsepower of different engine types, making it easier to understand the data and identify trends.
#
# Engine type is a categorical variable, making a bar plot a suitable choice for displaying the relationship between engine type and average horsepower.
# A bar plot makes it easy to compare the average horsepower of different engine types, allowing us to identify which engine types have higher or lower average horsepower.
# A bar plot provides a visual representation of the data, making it easy to see the relationship between engine type and average horsepower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of average horsepower vs engine type, we can gain insights into the performance of different engine types, informing business decisions and driving growth.
#
# The bar plot shows the average horsepower of different engine types, allowing us to compare and identify which engine types have higher or lower average horsepower. The bar plot makes it easy to identify the engine types with the highest and lowest average horsepower.
# The bar plot allows us to compare the average horsepower of different engine types, identifying which engine types have similar or different average horsepower.
# The bar plot can be used to identify trends and patterns in the data, such as which engine types have consistently higher or lower average horsepower.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of average horsepower vs engine type, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the bar plot can inform business decisions, such as which engine types to use in new products.
# The bar plot can be used to identify engine types with higher average horsepower, informing product development decisions.
# By identifying engine types with higher average horsepower, businesses can optimize their products and improve efficiency.
#
# By developing products with engine types that have higher average horsepower, businesses can increase sales.
# By analyzing the competition and identifying engine types with higher average horsepower, businesses can improve their market share.
# Enhanced brand reputation: By developing products with engine types that have higher average horsepower, businesses can enhance their brand reputation.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %%
min_value = df["city-mpg"].min()
max_value = df["city-mpg"].max()
print(min_value)
print(max_value)
# Out:
# 13
# 49

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="city-mpg",y="engine-size",data=df,color="blue")
plt.xlabel("AVERAGE MILEAGE",fontsize=15)
plt.ylabel("ENGINE SIZE",fontsize=15)
plt.title("MILEAGE ACCORDING TO ENGINE SIZE")
# Out:
# Text(0.5, 1.0, 'MILEAGE ACCORDING TO ENGINE SIZE')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a bar plot for mileage according to engine size, we can effectively visualize and compare the mileage of different engine sizes, making it easier to understand the data and identify trends.
#
# Engine size is a categorical variable, making a bar plot a suitable choice for displaying the relationship between engine size and mileage.
# A bar plot makes it easy to compare the mileage of different engine sizes, allowing us to identify which engine sizes have higher or lower mileage.
# A bar plot provides a visual representation of the data, making it easy to see the relationship between engine size and mileage.
# Bar plots are easy to interpret, even for non-technical audiences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of mileage according to engine size, we can gain insights into the fuel efficiency of different engine sizes, informing business decisions and driving growth.
#
# The bar plot shows the mileage of different engine sizes, allowing us to compare and identify which engine sizes have higher or lower mileage.
# The bar plot makes it easy to identify the engine sizes with the highest and lowest mileage.
# The bar plot allows us to compare the mileage of different engine sizes, identifying which engine sizes have similar or different mileage.
# The bar plot can be used to identify trends and patterns in the data, such as which engine sizes have consistently higher or lower mileage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of mileage according to engine size, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the bar plot can inform business decisions, such as which engine sizes to use in new products.
# The bar plot can be used to identify engine sizes with higher mileage, informing product development decisions.
# By identifying engine sizes with higher mileage, businesses can optimize their products and improve fuel efficiency.
# By understanding the mileage of different engine sizes, businesses can develop products that meet customer needs and preferences.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df["drive-wheels"].value_counts()
# Out:
# drive-wheels
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,10))
body_style = ['fwd','rwd','4wd']
quantity = [120,76,9]
pie1 = plt.pie(quantity,labels=body_style,autopct='%1.1f%%',radius=2)
pie2 = plt.pie([3],radius=1,colors="w")
plt.title("DRIVE WHEELS")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a pie plot for body style with percentage, we can effectively visualize and compare the distribution of different body styles, making it easier to understand the data and identify trends.
#
# Body style is a categorical variable, making a pie plot a suitable choice for displaying the distribution of different body styles.
# A pie plot is ideal for showing how different categories contribute to a whole, making it perfect for displaying percentages.
# A pie plot provides a visual representation of the data, making it easy to see the distribution of different body styles.
# Pie plots are easy to interpret, even for non-technical audiences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of body style with percentage, we can gain insights into the distribution of different body styles, informing business decisions and driving growth.
#
# The pie plot shows the distribution of different body styles, allowing us to compare and identify which body styles are most popular.
# The pie plot provides the percentage of each body style, making it easy to see which body styles are most common.
# The pie plot allows us to compare the percentage of different body styles, identifying which body styles are most popular.
# The pie plot can be used to identify trends and patterns in the data, such as which body styles are most popular among certain demographics.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of body style, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the pie plot can inform business decisions, such as which body styles to focus on or avoid.
# The pie plot can be used to identify body styles that are most popular, informing product development decisions.
# By focusing on body styles that are most popular, businesses can increase sales.
# By understanding the distribution of different body styles, businesses can develop products that meet customer needs and preferences.
#
# By analyzing the competition and identifying body styles that are most popular, businesses can increase their market share.
# By developing products that meet customer needs and preferences, businesses can improve their brand reputation.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# ### Chart - 10 visualization code

# %%
# Chart - 10 visualization code

# %%
df["aspiration"].value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
df["aspiration"].value_counts().plot(kind = "bar",width=0.2,color=sns.color_palette("Set2"),edgecolor="black")
plt.xlabel("ASPIRATION",fontsize=15)
plt.ylabel("COUNT",fontsize=15)
# Out:
# Text(0, 0.5, 'COUNT')

# %%
##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a bar plot for aspiration vs count, we can effectively visualize and compare the distribution of different aspiration categories, making it easier to understand the data and identify trends.
#
# Aspiration is a categorical variable, making a bar plot a suitable choice for displaying the count of each category.
# A bar plot makes it easy to compare the count of different aspiration categories.
# A bar plot provides a visual representation of the data, making it easy to see the distribution of aspiration categories.
# Bar plots are easy to interpret, even for non-technical audiences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of aspiration vs count, we can gain insights into the distribution of different aspiration categories, informing business decisions and driving growth.
#
# The bar plot shows the distribution of different aspiration categories, allowing us to compare and identify which categories are most common.
# The bar plot provides the count of each aspiration category, making it easy to see which categories are most popular.
# The bar plot allows us to compare the count of different aspiration categories, identifying which categories are most common.
# The bar plot can be used to identify trends and patterns in the data, such as which aspiration categories are most common among certain demographics.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of aspiration vs count, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the bar plot can inform business decisions, such as which aspiration categories to focus on or avoid.
# The bar plot can be used to identify aspiration categories that are most common, informing product development decisions.
# By focusing on aspiration categories that are most common, businesses can increase sales.
# By understanding the distribution of different aspiration categories, businesses can develop products that meet customer needs and preferences.
#
#
# By making informed decisions and developing products that meet customer needs and preferences, businesses can achieve sustainable growth.
# By understanding the market and competition, businesses can develop a competitive advantage, differentiating themselves from others.
# By optimizing products and improving efficiency, businesses can improve profitability.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %%
plt.figure(figsize=(10,4))
sns.lineplot(x="city-mpg",y="horsepower",data=df)
plt.xlabel("AVERAGE MILEAGE",fontsize=15)
plt.ylabel("HORSEPOWER",fontsize=15)
plt.title("MILEAGE VS HORSEPOWER")
# Out:
# Text(0.5, 1.0, 'MILEAGE VS HORSEPOWER')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a line chart for average mileage vs horsepower, we can effectively visualize and analyze the relationship between these two variables, making it easier to understand the data and identify trends.
#
# A line chart is ideal for showing the relationship between two continuous variables, such as average mileage and horsepower.
# A line chart makes it easy to identify trends and patterns in the data, such as how average mileage changes as horsepower increases.
# A line chart provides a clear and concise visual representation of the data, making it easy to understand the relationship between average mileage and horsepower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the line chart of average mileage vs horsepower, we can gain insights into the relationship between these two variables, informing business decisions and driving growth.
#
# The line chart shows the relationship between average mileage and horsepower, allowing us to see how average mileage changes as horsepower increases.
# The line chart makes it easy to identify trends and patterns in the data, such as whether average mileage increases or decreases as horsepower increases.
# The line chart allows for easy comparison of data points, making it easy to see how average mileage changes at different horsepower levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the line chart for average mileage vs horsepower, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the line chart can inform business decisions, such as which horsepower levels to focus on or avoid.
# The line chart can be used to identify horsepower levels that are most common, informing product development decisions.
# By understanding the relationship between average mileage and horsepower, businesses can develop products that are more fuel-efficient.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %%
x = df["body-style"]
y = df["price"]
plt.bar(x,y,color=sns.color_palette("magma"),width = 0.4)
plt.xlabel("BODY STYLE",fontsize=15)
plt.ylabel("PRICE",fontsize=15)
# Out:
# Text(0, 0.5, 'PRICE')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a bar plot for body style vs price, we can effectively visualize and compare the prices of different body styles, making it easier to understand the data and identify trends.
#
# Body style is a categorical variable, making a bar plot a suitable choice for displaying the relationship between body style and price.
# A bar plot makes it easy to compare the prices of different body styles.
# A bar plot provides a clear and concise visual representation of the data, making it easy to understand the relationship between body style and price.
# Bar plots are easy to interpret, even for non-technical audiences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the bar plot of body style vs price, we can gain insights into the relationship between these two variables, informing business decisions and driving growth.
#
# The bar plot allows us to compare the prices of different body styles.
# The bar plot can be used to identify trends in the data, such as which body styles are most expensive or least expensive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Yes, analyzing the bar plot of body style vs car price can have several positive business impacts.
# By analyzing the bar plot of body style vs car price, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# The insights gained from the bar plot can inform business decisions, such as which body styles to focus on or avoid.
# The bar plot can be used to identify body styles that are most popular or in demand, informing product development decisions.
# Increased sales: By understanding the relationship between body style and car price, businesses can develop products that meet customer needs and preferences, leading to increased sales.
# By understanding the relationship between body style and car price, businesses can develop products that meet customer needs and preferences, leading to enhanced customer satisfaction.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %%
df["engine-location"].value_counts().plot(kind = "pie",autopct="%1.1f%%",shadow=True,explode=[0.1,0.1],colors=sns.color_palette("Set1"))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a pie chart for engine location, we can effectively visualize and compare the distribution of different engine locations, making it easier to understand the data and identify trends.
#
# Engine location is a categorical variable, making a pie chart a suitable choice for displaying the distribution of different engine locations.
# A pie chart is ideal for showing how different engine locations contribute to the whole, making it easy to see the proportion of each category.
# A pie chart provides a clear and concise visual representation of the data, making it easy to understand the distribution of engine locations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of engine location, we can gain insights into the distribution of different engine locations, informing business decisions and driving growth.
#
# The pie plot shows which engine location is most common, making it easy to see which location is most popular.
# The pie plot shows which engine location is least common, making it easy to see which location is least popular.
# The pie plot can be used to identify engine locations that are similarly common, making it easy to see which locations are equally popular.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pie plot of engine location, businesses can gain valuable insights that can inform business decisions, drive growth, and improve customer satisfaction.
#
# By developing products that meet customer needs and preferences, businesses can increase customer loyalty.
# By analyzing the competition and identifying engine locations that are most popular, businesses can enhance their market position.
# By developing products that meet customer needs and preferences, businesses can improve brand awareness.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %%
plt.figure(figsize=(20,10))
New_df = df.select_dtypes(include=np.number)
sns.heatmap(New_df.corr(),annot=True)
plt.title("CORRELATION HEATMAP")
# Out:
# Text(0.5, 1.0, 'CORRELATION HEATMAP')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1]

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# The correlation heat map shows the correlation between different variables in the dataset, making it easy to identify patterns and relationships.
# The correlation heat map shows the strength of the correlation between variables, making it easy to see which variables are most strongly correlated.
# The correlation heat map shows both positive and negative correlations between variables, making it easy to see which variables are related in a positive or negative way.
# The correlation heat map can be used to identify clusters of variables that are highly correlated with each other.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# By using a pair plot for the automobile dataset, we can effectively visualize and analyze the relationships between multiple variables, making it easier to understand the data and identify patterns.
#
# Use a pair plot when working with multivariate data, such as the automobile dataset.
# Use a pair plot when you want to show the relationships between multiple variables.
# Use a pair plot when you want to provide a clear and concise visual representation of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# By analyzing the pair plot of the automobile dataset, we can gain insights into the relationships between multiple variables, informing business decisions and driving growth.
#
# The pair plot shows the relationships between multiple variables, making it easy to identify patterns and correlations.
# The pair plot can be used to identify correlations between variables, such as positive or negative correlations.
# The pair plot shows the distribution of each variable, making it easy to see the shape of the data.
# The pair plot can be used to identify outliers and anomalies in the data.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# 1)Develop a predictive model: Build a predictive model to forecast vehicle sales, revenue growth, and customer satisfaction.
#
# 2)Improve vehicle design: Use data analysis and machine learning techniques to optimize vehicle design.
#
# 3)Enhance customer experience: Analyze customer feedback, ratings, and reviews to identify areas for improvement in vehicle quality.
#
# 4)Sales growth: Monitor sales growth and revenue increase.
#
# 5)Customer satisfaction: Track customer satisfaction ratings and feedback.
#
# 6)Return on investment (ROI): Evaluate the ROI on data-driven initiatives and investments.
#
# 7)Exploratory data analysis: Perform exploratory data analysis to identify patterns, trends, and correlation.
#
# 8)Recommendation system: Build a recommendation system to suggest vehicles to customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# **This analysis provided valuable insights into the automobile market, highlighting trends, patterns, and correlations between vehicle attributes and performance metrics. The findings can inform business strategies, product development, and marketing initiatives for manufacturers and industry stakeholders. By understanding the relationships between vehicle attributes and performance metrics, manufacturers can optimize their designs, improve fuel efficiency, and develop effective pricing strategies. Additionally, the identification of distinct vehicle clusters can inform targeted marketing initiatives and product development strategies**
#
# **This project demonstrates the process of building a predictive model using real-world automobile data. It involves crucial steps such as data cleaning, feature engineering, and model evaluation, showcasing the power of Python and machine learning tools to solve practical problems in the automotive industry. By understanding vehicle attributes and their relationships, businesses or consumers can make better-informed decisions**

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
